# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from ecoindex.transform import hellinger_transform, log1p_standardize, log10p_standardize

# %%
df = pd.read_excel("/Users/gufeng/2025_winter/Thesis_Project/ThesisProject/Proposal/data/processed_data/taxa_data.xlsx",
                   index_col = 0)

H = hellinger_transform(df)
Z = log1p_standardize(df)  # for chem features in another notebook
T = log10p_standardize(df)
H.describe()
# Out:
#         Oligochaeta      Nematoda  Chironomidae  Ceratopogonidae  \
# count  3.110000e+02  3.110000e+02  3.110000e+02     3.110000e+02
# mean   5.345113e-01  2.946794e-01  3.741895e-01     3.521821e-02
# std    1.824778e-01  1.872366e-01  1.880447e-01     9.228236e-02
# min    4.432529e-09  3.322864e-09  3.814048e-09     3.197257e-09
# 25%    4.320174e-01  1.264390e-01  2.637160e-01     4.084045e-09
# 50%    5.242821e-01  3.277856e-01  4.155162e-01     4.585002e-09
# 75%    6.360297e-01  4.329955e-01  5.201536e-01     5.566307e-09
# max    1.000000e+00  7.248369e-01  7.878516e-01     4.731574e-01
#
#           Hexagenia        Caenis  Hydropsychidae  Other Trichoptera  \
# count  3.110000e+02  3.110000e+02    3.110000e+02       3.110000e+02
# mean   7.517119e-02  6.454400e-02    7.138195e-02       4.574540e-02
# std    1.277332e-01  1.231688e-01    1.253519e-01       8.891000e-02
# min    3.197257e-09  3.197257e-09    3.302285e-09       3.302285e-09
# ...
