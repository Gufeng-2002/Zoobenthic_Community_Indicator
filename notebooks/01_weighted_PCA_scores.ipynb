# %% [markdown]
# ##  Recons: test the `weighted_PCA_computation` function

# %% [markdown]
# ### Prepare the data

# %%
# magic commands to make sure external modules are reloaded every complete run
# %load_ext autoreload
# %autoreload 2

import pandas as pd

# read the merged dataframe
master = pd.read_excel("../data/processed/complete_env_taxa_chemical.xlsx", 
                      sheet_name="all_data_merged", 
                      header=[0, 1, 2], 
                      index_col=0)

master.head()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# block     sample_info                           environmental            \
# subblock          raw                                     raw
# var          Latitude Longitude Waterbody  Year       LOI (%) MPS (Phi)
# StationID
# A10          42.90455 -82.46760       SCR  2004      3.436193  1.734259
# A23          42.56658 -82.57595       LSC  2004      3.226637  1.969984
# A27          42.56007 -82.42132       LSC  2004      2.802642  1.319519
# A28          42.54577 -82.42073       LSC  2004      3.201399  1.398687
# A29          42.51440 -82.43462       LSC  2004      6.180718  1.065748
#
# block                                                                      \
# subblock
# var       Measured Depth (m) Temperature (oC) Velocity  at bottom (m/sec)
# StationID
# A10                      1.8            19.17                         NaN
# A23                      3.0            19.10                         NaN
# A27                      1.0            18.40                         NaN
# A28                      0.5            18.90                         NaN
# A29                      0.5            19.30                         NaN
#
# block                             ...           taxa                          \
# subblock                          ...            raw
# var       Water DO Bottom (mg/L)  ... Hydropsychidae      Hydrozoa  Nematoda
# StationID                         ...
# A10                        10.21  ...   3.203427e-16  3.203427e-16  1.727234
# A23                        10.09  ...   3.203427e-16  3.203427e-16  2.427993
# A27                        10.30  ...   3.203427e-16  3.203427e-16  1.802219
# A28                        12.80  ...   3.203427e-16  3.203427e-16  2.771800
# A29                         9.70  ...   3.203427e-16  3.203427e-16  4.616441
#
# block                                                                \
# subblock
# var       Oligochaeta Other Trichoptera   Sphaeriidae   Turbellaria
# StationID
# A10          6.576942      3.203427e-16  3.203427e-16  3.203427e-16
# A23          5.872905      3.203427e-16  1.022139e+00  5.997595e-01
# A27          6.402280      1.580169e+00  1.317615e+00  9.964067e-01
# A28          5.867874      2.049287e+00  2.863547e+00  3.203427e-16
# A29          5.181664      3.203427e-16  3.203427e-16  3.203427e-16
#
# block     2008_results
# subblock   DR_clusters       corridor_clusters
# var         DR_cluster if_RF  corridor_cluster
# StationID
# A10                  0     0                 1
# A23                  0     0                 1
# A27                  0     0                 1
# A28                  0     0                 1
# A29                  0     0                 1
#
# [5 rows x 59 columns]

# %%
from zci.data_process.dataframe_ops import get_block
from sklearn.preprocessing import StandardScaler

# take the stressor data block
stressor = get_block(master, block="chemical", subblock= "raw")

# transform the stressor features: standardization (z-score)
scaler = StandardScaler()
stressor = pd.DataFrame(scaler.fit_transform(stressor), 
                       columns=stressor.columns, 
                       index=stressor.index)
stressor.describe()
# Out:
# var             %OC      1234-TCB      1245-TCB            Al            As  \
# count  1.040000e+02  1.040000e+02  1.040000e+02  1.040000e+02  1.040000e+02
# mean  -2.284497e-16 -8.540177e-18 -3.416071e-17 -1.024821e-16 -3.416071e-17
# std    1.004843e+00  1.004843e+00  1.004843e+00  1.004843e+00  1.004843e+00
# ## Set var-type mapping and their weights

# %%
# import the chemical weighting utilities
from zci.sediment_pollution_assessment.chemical_weights import (
    build_weights_for_columns, # function to build weight mapping for variables
    VARIABLE_TYPE_BY_NAME, # default category mapping for: variable name -> variable type
)

# define weights for different variable types
chem_cols = stressor.columns.tolist()

# specify custom weights for certain types (others will use defaults)
std_weight = 3

type_weights = {
    "Trace Metal (pollutant)":  1 * std_weight,
    "Hydrocarbon pollutant": 1 * std_weight,        # Highest priority: petroleum/chlorobenzenes
    "organochlorine pesticide": 1 * std_weight,     # Highest priority: POPs
    "Sum of all PCBs": 1 * std_weight,              # Highest priority: PCBs
    "Binding agent": 1 * std_weight,               # Medium priority: affects bioavailability
    "Earth element (nontoxic)": .5 * std_weight   # Lowest priority: background elements
}

# Build the final weight map for the variables for later use in weighted PCA
custom_weight_map = build_weights_for_columns(chem_cols,
                                              variable_type_by_name =VARIABLE_TYPE_BY_NAME,
                                              type_weights=type_weights,
                                              weights_by_name={"mirex": std_weight} # set a subtle weight for Sb specifically
                                             )

# %%
# Create a DataFrame to visualize the weight assignments
weight_analysis = []
for var in chem_cols:
    var_type = VARIABLE_TYPE_BY_NAME.get(var, "Unclassified")
    weight = custom_weight_map.get(var, 1.0)
    weight_analysis.append({
        'Variable': var,
        'Type': var_type,
        'Weight': weight
    })

weight_df = pd.DataFrame(weight_analysis)

# Group by type and show weight distribution
print("Weight Distribution by Variable Type:")
print("=" * 40)
weight_summary = weight_df.groupby(['Type', 'Weight']).size().reset_index(name='Count')
for _, row in weight_summary.iterrows():
    print(f"{row['Type']}: Weight {row['Weight']} ({row['Count']} variables)")

print(f"\nTotal variables: {len(weight_df)}")
print(f"Unique weights: {sorted(weight_df['Weight'].unique())}")
# Out:
# Weight Distribution by Variable Type:
# ========================================
# Binding agent: Weight 3.0 (1 variables)
# Earth element (nontoxic): Weight 1.5 (6 variables)
# Hydrocarbon pollutant: Weight 3.0 (5 variables)
# Sum of all PCBs: Weight 3.0 (1 variables)
# Trace Metal (pollutant): Weight 3.0 (13 variables)
# organochlorine pesticide: Weight 3.0 (4 variables)
#
# Total variables: 30
# Unique weights: [np.float64(1.5), np.float64(3.0)]

# %% [markdown]
# ## Pass the transformed data and custom weights to the weighted PCA function

# %%
from zci.sediment_pollution_assessment.weighted_pca import weighted_PCA_computation

results = weighted_PCA_computation(stressor, custom_weight_map)

# %% [markdown]
# ## Got the wanted results - loadings and scores

# %%
results.loadings
# Out:
#                          PC1       PC2       PC3       PC4       PC5  \
# var
# %OC                 0.241716 -0.195603 -0.017880  0.201237  0.086976
# 1234-TCB            0.050927 -0.016168 -0.027264  0.059426  0.106841
# 1245-TCB            0.041613 -0.125524  0.448045  0.015665  0.068082
# Al                  0.112088 -0.141453 -0.048812  0.082076 -0.039415
# As                  0.158507 -0.152563 -0.126190 -0.032514 -0.215693
# Bi                 -0.171583  0.028656  0.124752  0.367341  0.428480
# Ca                  0.052903 -0.100280  0.078028  0.121890  0.130932
# Cd                  0.200483  0.190093  0.159807  0.242901  0.230591
# 1245-TCB           -0.128562 -0.004241 -0.026837 -0.013793 -0.001015
# Al                  0.144751  0.448639 -0.107345  0.222424  0.717647
# As                  0.020959  0.086615 -0.017837  0.009179 -0.016102
# Bi                 -0.048736  0.018873 -0.046025  0.036880  0.000443
# Ca                 -0.013632 -0.158930  0.290366  0.067211  0.010904
# Cd                  0.087076 -0.002670  0.012086  0.077694  0.059172
# Co                 -0.119162 -0.113940  0.474673  0.082246 -0.028359
# Cr                 -0.085550  0.160503  0.328190  0.092109 -0.136680
# Cu                 -0.022957 -0.323299  0.053451  0.362659 -0.023866
# Fe                 -0.110473 -0.201067 -0.464082  0.645749 -0.141656
# HCB                -0.531006  0.153798 -0.044588 -0.172358 -0.008450
# Heptachlor Epoxide -0.020471 -0.002066 -0.002240 -0.008454 -0.004293
# Hg                 -0.123421 -0.023445 -0.043211  0.049621  0.008515
# K                   0.283657  0.459270 -0.151942 -0.006066 -0.651199
# Mg                 -0.091475  0.127559 -0.129319 -0.087460 -0.019486
# Mn                 -0.005185  0.019507  0.045498 -0.041647  0.019467
# Na                  0.079555  0.136961 -0.228016  0.020126  0.022642
# Ni                  0.133100 -0.454336 -0.410777 -0.489531  0.084182
# OCS                -0.104585  0.036928 -0.020946  0.023134 -0.024904
# Pb                  0.080705  0.105091  0.143377 -0.182945  0.019053
# QCB                 0.682991 -0.119378  0.158665  0.047533  0.034703
# Sb                 -0.007015 -0.024608 -0.009871 -0.016778 -0.011843
# V                  -0.086709 -0.056539 -0.031563 -0.211629  0.039265
# Zn                 -0.105496  0.220751 -0.080362 -0.019274 -0.007083
# mirex               0.020985 -0.014662 -0.002881 -0.003303 -0.012577
# p,p'-DDD            0.026015  0.023787 -0.089025  0.005671 -0.030288
# p,p'-DDE           -0.017088 -0.007895  0.035319  0.027357  0.014766
# total PCB           0.040338  0.156262 -0.124086 -0.099565  0.055454
#
# [30 rows x 30 columns]

# %% [markdown]
# ## Test the PCs filtering function

# %%
from zci.sediment_pollution_assessment.weighted_pca import PCs_filter_loading_vs_weight

# Use custom_weight_map instead of results.weights since that's what the function expects
selected_PCs = PCs_filter_loading_vs_weight(results.loadings, custom_weight_map,
                             results.explained_var_ratio, weight_threshold=3.0)
# Out:
# === Selected Principal Components ===
# PC       Explained Var   High-Weighted Variable Loadings
# --------------------------------------------------------------------------------
# PC3      0.1207          %OC: -0.018, 1234-TCB: -0.027, 1245-TCB: 0.448, As: -0.126, Bi: 0.125, Cd: 0.160, Co: -0.029, Cr: -0.028, Cu: -0.035, HCB: 0.408, Heptachlor Epoxide: 0.054, Hg: 0.210, Mn: -0.061, Ni: -0.022, OCS: 0.467, Pb: 0.027, QCB: 0.505, Sb: 0.057, V: -0.118, Zn: -0.006, mirex: 0.023, p,p'-DDD: 0.067, p,p'-DDE: -0.043, total PCB: 0.059
# PC8      0.0308          %OC: 0.004, 1234-TCB: 0.516, 1245-TCB: 0.192, As: 0.562, Bi: -0.086, Cd: 0.159, Co: -0.173, Cr: -0.113, Cu: -0.053, HCB: -0.227, Heptachlor Epoxide: 0.224, Hg: 0.106, Mn: 0.008, Ni: -0.122, OCS: 0.131, Pb: 0.005, QCB: -0.101, Sb: -0.220, V: -0.091, Zn: -0.002, mirex: -0.062, p,p'-DDD: 0.017, p,p'-DDE: -0.166, total PCB: -0.027
# --------------------------------------------------------------------------------
# Total selected PCs: 2
# High-weighted variables (24): %OC, 1234-TCB, 1245-TCB, As, Bi, Cd, Co, Cr, Cu, HCB, Heptachlor Epoxide, Hg, Mn, Ni, OCS, Pb, QCB, Sb, V, Zn, mirex, p,p'-DDD, p,p'-DDE, total PCB

# %% [markdown]
# ## Compute the pollution scores

# %%
from zci.sediment_pollution_assessment.weighted_pca import pollution_scores_of_subPCs

# Use the selected_pcs list from the FilteredPCsResult object
pollution_scores_labels = pollution_scores_of_subPCs(
    results.scores,
    selected_PCs,  # Access the selected_pcs attribute
    with_group_labels=True,
)

pollution_scores_labels
# Out:
#            pollution_score pollution_quality
# StationID
# A10               2.409766          degraded
# A23               2.639359          degraded
# A27              -3.212672            medium
# A28              -4.702575         reference
# A29              -8.582572         reference
# ...                    ...               ...
# S99               0.081206            medium
# UBC1             17.733103          degraded
# UCC1              5.529670          degraded
# UCE1              0.041230            medium
# UJC1             22.791040          degraded
#
# [104 rows x 2 columns]

# %% [markdown]
# ## Use some metrics to evaluate the ordination results
#
# - It is expected to see the weighted reference group has smaller raw stressor means than the degraded group, especially for the high-weighted stressors.
# - The

# %%
from zci.sediment_pollution_assessment.ordination_metrices import groupby_aggregation

# take out the original raw stressor data
stressor = get_block(master, block="chemical", subblock= "raw")
stressor
# Out:
# var             %OC  1234-TCB   1245-TCB     Al     As        Bi     Ca  \
# StationID
# A10        3.436193  0.835583   0.775732   3041  1.939  18.45000  28170
# A23        3.226637  0.639983   0.697265   4483  2.512  17.03000  42110
# A27        2.802642  0.451838   0.815149  13620  2.759   0.05370  41610
# A28        3.201399  0.224379   0.483363  12750  2.609   0.06617  33280
# A29        6.180718  0.299715   0.695356  23740  3.735   0.15290  40450
# ...             ...       ...        ...    ...    ...       ...    ...
# S99        0.863939  0.655186   0.951855   2826  1.214  15.12000  14960
# UBC1       2.890000  0.000000  12.135559   6757  1.581  21.01000  43310
# UCC1       3.120000  0.000000   4.319792   5945  2.260  23.62000  50540
# UCE1       2.210000  0.000000   0.552417   7050  4.475   0.00010  38090
# UJC1       3.440000  0.000000  11.243048   5070  2.713  19.72000  45230
#
# var            Cd     Co      Cr  ...        OCS      Pb       QCB       Sb  \
# StationID                         ...
# A10        0.2950  2.723   8.766  ...   0.283217   6.515  0.125824  25.8300
# A23        0.3986  4.009  10.850  ...   0.000000   4.873  0.927448   8.5750
# A27        0.2180  6.273  21.080  ...   0.454157   5.020  0.114867   0.0000
# A28        0.1197  5.824  18.700  ...   0.144927   4.570  0.224762   0.0000
# A29        0.1536  9.618  44.370  ...   0.831924   9.589  0.373344   0.1145
# ...           ...    ...     ...  ...        ...     ...       ...      ...
# S99        0.3079  4.025  12.260  ...   0.000000   5.694  0.299569   8.8310
# UBC1       0.5146  5.263  12.800  ...  11.866067   7.165  4.612587  13.1000
# UCC1       0.5658  5.303  11.400  ...   3.740394   6.243  2.619405  14.8200
# UCE1       0.3449  6.232  11.860  ...   1.958172  11.860  0.896698   0.0010
# UJC1       0.6496  5.213  11.220  ...  16.210058   7.143  7.056736  12.1400
#
# var            V     Zn     mirex  p,p'-DDD  p,p'-DDE  total PCB
# StationID
# A10        13.62  39.01  0.000000  0.523188  0.239245   2.493820
# A23        15.18  41.31  0.193857  0.781357  0.452774   6.775272
# A27        28.66  56.28  0.514213  1.825673  0.458433   7.429817
# A28        26.02  52.70  0.000000  1.867356  0.586789   2.122595
# A29        43.92  95.80  0.986737  0.374731  0.497881   5.937485
# ...          ...    ...       ...       ...       ...        ...
# S99        18.03  49.17  0.196919  0.637274  0.676699   5.867293
# UBC1       18.37  46.74  0.000000  0.000000  0.000000  18.240493
# UCC1       17.04  45.90  0.000000  0.000000  0.000000  16.153581
# UCE1       20.34  39.66  0.000000  0.930022  0.000000   4.124299
# UJC1       15.82  57.93  0.000000  0.000000  0.000000  23.591279
#
# [104 rows x 30 columns]

# %%
groupby_aggregation(
    stressor,
    quality_labels = pollution_scores_labels['pollution_quality'],
    custom_weights = custom_weight_map
)
# Out:
# quality_label             reference      medium    degraded
# var
# %OC                mean    2.876620    1.754525    2.863279
#                    std     1.963693    0.935215    1.358539
# 1234-TCB           mean    0.089616    0.265820    0.325094
#                    std     0.134935    0.257537    0.316622
# 1245-TCB           mean    0.348832    0.419533    3.347839
#                    std     0.296241    0.303055    3.653897
# As                 mean    1.850300    1.802292    2.591333
#                    std     1.468259    1.200746    1.458620
# Bi                 mean   14.365953   17.721889   19.601983
#                    std    12.454886    8.998266   10.344194
# Cd                 mean    0.274936    0.299882    0.727203
#                    std     0.220176    0.190069    0.651356
# Co                 mean    5.732429    3.625274    4.768333
#                    std     2.941759    1.228555    1.382011
# Cr                 mean   18.744238    8.681839   15.864381
#                    std    17.423432    4.167669   17.180706
# Cu                 mean   28.612476   11.114616   21.594019
#                    std    45.510801    8.314110   23.437042
# HCB                mean    1.204266    2.447526   45.969273
#                    std     2.104696    5.049308  134.785256
# Heptachlor Epoxide mean    0.000000    0.039239    0.215848
#                    std     0.000000    0.130019    0.457212
# Hg                 mean    0.159452    0.190341    0.940958
#                    std     0.159865    0.244731    1.369097
# Mn                 mean  214.305238  158.372903  192.368095
#                    std   114.597844   67.331640   54.838687
# Ni                 mean   16.677095    8.680516   14.382619
#                    std    11.556214    4.192224    8.292323
# OCS                mean    0.253768    0.433776    4.765072
#                    std     0.330564    0.544499    6.141170
# Pb                 mean   13.596571    6.073258   16.356762
#                    std    35.750233   11.761274   35.327640
# QCB                mean    0.346070    0.446575    3.279821
#                    std     0.231909    0.331539    4.620173
# Sb                 mean   15.864410   17.689323   16.787214
#                    std    14.365867   12.462390   12.853062
# V                  mean   22.838429   14.596258   17.977619
#                    std    13.406045    5.487581    4.804792
# Zn                 mean   61.987143   35.065419   60.799524
#                    std    68.485846   19.202230   48.614961
# mirex              mean    0.171504    0.181529    0.314179
#                    std     0.327888    0.268486    0.783267
# p,p'-DDD           mean    0.756302    0.870674    4.433136
#                    std     1.136816    1.194391   16.259769
# p,p'-DDE           mean    0.662888    0.426660    0.559570
#                    std     1.464449    0.355272    1.412141
# total PCB          mean   16.291840    6.162687   21.025760
#                    std    59.457254   12.831544   32.445280

# %% [markdown]
# ## Try the pipeline function: stressors -> composite_scores

# %%
from zci.sediment_pollution_assessment.weighted_pca import WeightedPCA_Scores
from zci.sediment_pollution_assessment.chemical_weights import (
    build_weights_for_columns, # function to build weight mapping for variables
    VARIABLE_TYPE_BY_NAME, # default category mapping for: variable name -> variable type
)

# prepare the raw data 
stressor = get_block(master, block="chemical", subblock= "raw")

# define weights for different variable types
chem_cols = stressor.columns.tolist()
# specify custom weights for certain types (others will use defaults)
std_weight = 1

type_weights = {
    "Trace Metal (pollutant)":  3 * std_weight,
    "Hydrocarbon pollutant": 1 * std_weight,        # Highest priority: petroleum/chlorobenzenes
    "organochlorine pesticide": 1 * std_weight,     # Highest priority: POPs
    "Sum of all PCBs": 1 * std_weight,              # Highest priority: PCBs
    "Binding agent": 1 * std_weight,               # Medium priority: affects bioavailability
    "Earth element (nontoxic)": 1 * std_weight   # Lowest priority: background elements
}

# Build the final weight map for the variables for later use in weighted PCA
custom_weight_map = build_weights_for_columns(chem_cols,
                                              variable_type_by_name =VARIABLE_TYPE_BY_NAME,
                                              type_weights=type_weights,
                                              weights_by_name={"Bi": 1 * std_weight,
                                                               "mirex": 1 * std_weight} # set a subtle weight for Sb specifically
                                             )

# %%
# transform the stressor features: standardization (z-score)
scaler = StandardScaler()
stressor_normalized = pd.DataFrame(scaler.fit_transform(stressor), 
                       columns=stressor.columns, 
                       index=stressor.index)

# set the custom weights as before
weighted_pca_pipeline = WeightedPCA_Scores(
    custom_weights = custom_weight_map,
    weight_threshold = 3.0
)

scores_with_labels = weighted_pca_pipeline.fit_transform(stressor_normalized)
# Out:
# === Selected Principal Components ===
# PC       Explained Var   High-Weighted Variable Loadings
# --------------------------------------------------------------------------------
# PC1      0.4911          As: 0.191, Cd: 0.213, Co: 0.291, Cr: 0.352, Cu: 0.313, Hg: 0.162, Mn: 0.282, Ni: 0.370, Pb: 0.258, Sb: -0.225, V: 0.282, Zn: 0.335
# PC2      0.1884          As: -0.241, Cd: 0.325, Co: -0.323, Cr: 0.160, Cu: 0.228, Hg: 0.347, Mn: -0.305, Ni: -0.072, Pb: 0.392, Sb: 0.168, V: -0.358, Zn: 0.183
# PC3      0.0832          As: -0.172, Cd: 0.454, Co: 0.207, Cr: -0.082, Cu: -0.308, Hg: 0.415, Mn: 0.154, Ni: 0.065, Pb: -0.221, Sb: 0.429, V: 0.145, Zn: -0.159
# PC5      0.0399          As: 0.629, Cd: 0.109, Co: -0.145, Cr: -0.048, Cu: 0.104, Hg: -0.186, Mn: 0.181, Ni: -0.064, Pb: 0.072, Sb: 0.551, V: -0.034, Zn: 0.122
# PC6      0.031           As: -0.095, Cd: -0.309, Co: 0.206, Cr: 0.155, Cu: 0.027, Hg: 0.180, Mn: -0.247, Ni: 0.073, Pb: 0.056, Sb: 0.265, V: 0.311, Zn: -0.185
# PC7      0.0244          As: 0.091, Cd: 0.565, Co: 0.006, Cr: 0.161, Cu: -0.258, Hg: -0.297, Mn: -0.357, Ni: 0.093, Pb: -0.317, Sb: -0.222, V: 0.017, Zn: 0.143
# --------------------------------------------------------------------------------
# Total selected PCs: 6
# High-weighted variables (12): As, Cd, Co, Cr, Cu, Hg, Mn, Ni, Pb, Sb, V, Zn

# %%
from skbio.stats.distance import permanova, DistanceMatrix
# compute the distance matrix
from scipy.spatial.distance import pdist, squareform

X = get_block(master, block="taxa", subblock= "raw").dropna(axis = 1)

# %%
groupby_aggregation(
    X,
    quality_labels = scores_with_labels['pollution_quality'],
    custom_weights = custom_weight_map
)
# Out:
# Warning: No variables found with weight >= 3
# quality_label           reference    medium  degraded
# var
# Acari             mean   0.585436  0.353971  0.415328
#                   std    0.901534  0.592677  0.782379
# Amphipoda         mean   0.808048  0.615111  0.698731
#                   std    1.297502  1.211761  1.003307
# Caenis            mean   0.459978  0.541012  0.841007
#                   std    0.831290  1.119736  1.283508
# Ceratopogonidae   mean   0.090616  0.114230  0.024192
#                   std    0.415254  0.386387  0.110864
# Chironomidae      mean   3.751569  4.430302  4.302486
#                   std    1.819050  1.275914  1.332734
# Dreissena         mean   1.728180  1.249679  0.778086
#                   std    2.433508  1.852080  1.482652
# Gastropoda        mean   1.053467  0.707438  0.849001
#                   std    1.608485  1.164480  1.203267
# Hexagenia         mean   0.457131  0.687282  0.437479
#                   std    1.224899  0.952713  0.812407
# Hirudinea         mean   0.172435  0.286908  0.182111
#                   std    0.624686  0.716261  0.571415
# Hydropsychidae    mean   0.097533  0.513686  0.837203
#                   std    0.446953  1.199912  1.651791
# Hydrozoa          mean   0.637137  0.246300  0.323983
#                   std    1.190072  0.905647  0.776384
# Nematoda          mean   2.591713  2.561153  2.713526
#                   std    1.986926  1.546815  1.629275
# Oligochaeta       mean   4.728771  5.132825  5.250999
#                   std    1.462499  1.147592  1.069091
# Other Trichoptera mean   0.144894  0.465858  0.704728
#                   std    0.455162  0.970652  1.323125
# Sphaeriidae       mean   1.221961  0.733423  0.711630
#                   std    1.531984  1.009294  1.141674
# Turbellaria       mean   0.593683  0.425779  0.213002
#                   std    0.888178  0.819804  0.394064

# %%
groups = scores_with_labels['pollution_quality']

dist_mat = squareform(pdist(X, metric='euclidean'))

# Convert to skbio DistanceMatrix
dm = DistanceMatrix(dist_mat, ids=X.index)

# perform PERMANOVA
permanova_results = permanova(dm, groups, permutations=999)
print(permanova_results)
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                     104
# number of groups                  3
# test statistic             1.044472
# p-value                       0.375
# number of permutations          999
# Name: PERMANOVA results, dtype: object
